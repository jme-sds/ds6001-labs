# %% [markdown]
# # Live Session 03: JSON

# %%
import numpy as np
import pandas as pd
import requests
import json

cocktail = 'http://www.thecocktaildb.com/api/json/v1/1/filter.php?c=Cocktail'

# %% [markdown]
# ## First demo a dictionary:
# * no concept of order
# * repeated elements of list
# * ability to name each element; name is key, element is value

# %%
mylist = [1,2,2,3]
myset = {1,2,2,3}

mylist, myset
# Out:
# ([1, 2, 2, 3], {1, 2, 3})

# %%
myset = {'larry':1,'curly':2,'moe':2,'shemp':3}
myset
# Out:
# {'larry': 1, 'curly': 2, 'moe': 2, 'shemp': 3}

# %%
myset['moe']
# Out:
# 2

# %% [markdown]
# ## CocktailDB

# %%
r = requests.get(cocktail)

# %%
#r.json()
myjson = json.loads(r.text)

# %%
myjson['drinks'][0]['strDrinkThumb']
# Out:
# 'https://www.thecocktaildb.com/images/media/drink/yqvvqs1475667388.jpg'

# %% [markdown]
# * Records: list of equivalently formatted dictionaries that you want to become **rows** in dataframe.
# * Record Path: sequence of json keys you need to delve into to get to records
#
# In this case, record path is just `drinks`

# %%
cocktail_df = pd.json_normalize(myjson,record_path=['drinks'])
cocktail_df
# Out:
#                                strDrink  \
# 0                           155 Belmont
# 1   57 Chevy with a White License Plate
# 2                             747 Drink
# 3                           9 1/2 Weeks
# 4                   A Gilligan's Island
# ..                                  ...
# 95                           Miami Vice
# 96                            Michelada
# 97                        Midnight Mint
# 98                               Mojito
# 99                         Mojito Extra
#
#                                         strDrinkThumb idDrink
# 0   https://www.thecocktaildb.com/images/media/dri...   15346
# 1   https://www.thecocktaildb.com/images/media/dri...   14029
# 2   https://www.thecocktaildb.com/images/media/dri...  178318
# 3   https://www.thecocktaildb.com/images/media/dri...   16108
# 4   https://www.thecocktaildb.com/images/media/dri...   16943
# ..                                                ...     ...
# 95  https://www.thecocktaildb.com/images/media/dri...   13936
# 96  https://www.thecocktaildb.com/images/media/dri...  178343
# 97  https://www.thecocktaildb.com/images/media/dri...   14842
# 98  https://www.thecocktaildb.com/images/media/dri...   11000
# 99  https://www.thecocktaildb.com/images/media/dri...   15841
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Wikipedia API

# %%
wiki = 'https://en.wikipedia.org/w/api.php?action=query&list=search&srsearch=Virginia&format=json&srlimit=500'

# %%
r = requests.get(wiki)
r
# Out:
# <Response [200]>

# %%
wiki_df = pd.json_normalize(r.json(),record_path=['query','search'])
wiki_df
# Out:
#      ns                                              title    pageid    size  \
# 0     0                                           Virginia     32432  287974
# 1     0                                      West Virginia     32905  184361
# 2     0                                           Virgínia   1392216    2105
# 3     0                           Virginia Beach, Virginia     91239  153586
# 4     0            List of municipalities in West Virginia  47238088   40526
# ..   ..                                                ...       ...     ...
# 495   0                           Virginia State Route 605  55991673   37374
# 496   0                                   McLean, Virginia    137582   22464
# 497   0            University of Virginia secret societies   3477032   41577
# 498   0  1976 United States Senate election in West Vir...  27887354    4168
# 499   0                                Culture of Virginia  21241504   26763
#
#      wordcount                                            snippet  \
# 0        24676  <span class="searchmatch">Virginia</span>, off...
# 1        18090  West <span class="searchmatch">Virginia</span>...
# 2           32  <span class="searchmatch">Virgínia</span> is a...
# 3        13654  <span class="searchmatch">Virginia</span> Beac...
# 4           88  West <span class="searchmatch">Virginia</span>...
# ..         ...                                                ...
# 495       1810  State Route 605 (SR 605) in the U.S. state of ...
# 496       1970  unincorporated community and census-designated...
# 497       4083  Secret societies have been a part of Universit...
# 498        158  The 1976 United States Senate election in West...
# 499       2653  Culture of <span class="searchmatch">Virginia<...
#
#                 timestamp
# 0    2025-01-25T07:28:48Z
# 1    2025-01-21T13:04:57Z
# 2    2024-11-11T14:52:44Z
# 3    2025-01-28T18:28:12Z
# 4    2024-11-14T16:04:32Z
# ..                    ...
# 495  2025-01-18T10:00:56Z
# 496  2025-01-26T11:33:52Z
# 497  2025-01-22T14:20:43Z
# 498  2024-09-22T04:13:13Z
# 499  2024-07-29T03:18:15Z
#
# [500 rows x 7 columns]

# %% [markdown]
# ## News API
#
# Warning: don't paste API key in code, hide with .env file

# %%
api = '3aedad5898744e41bb68bf84ec66a6ee'

# %%
url = 'https://newsapi.org/v2/everything'
parameters = {'apiKey':api,
              'q':'otter'}

r = requests.get(url,params=parameters)
news_df = pd.json_normalize(r.json(),record_path=['articles'])
news_df.head()
# Out:
#                    author                                              title  \
# 0  Manuela López Restrepo  Invasive green crabs threaten West Coast ecosy...
# 1              Tomás Mier  Catherine O’Hara, Seth Rogen Riff About Winnin...
# 2     ZEIT ONLINE: News -  Unfälle: Nach Tod von 17-Jährigem: Todesursach...
# 3     ZEIT ONLINE: News -  Unfälle: 17-Jähriger stürzt und stirbt auf Nac...
# 4           CaLea Johnson  Otters Are Keeping Invasive Crabs Under Contro...
#
#                                          description  \
# 0  As invasive green crabs wreak havoc on Califor...
# 1  "I lost half a nipple!" joked O'Hara about sta...
# 2  Hier finden Sie Informationen zu dem Thema „Un...
# 3  Hier finden Sie Informationen zu dem Thema „Un...
# 4  A new study shows that hungry sea otters are k...
#
#                                                  url  \
# 0  https://www.npr.org/2025/01/15/g-s1-42894/gree...
# 1  http://www.rollingstone.com/tv-movies/tv-movie...
# 2  https://www.zeit.de/news/2025-01/20/nach-tod-v...
# 3  https://www.zeit.de/news/2025-01/14/17-jaehrig...
# 4  https://www.mentalfloss.com/otters-keep-invasi...
#
#                                           urlToImage           publishedAt  \
# 0  https://npr.brightspotcdn.com/dims3/default/st...  2025-01-15T18:50:54Z
# 1  https://www.rollingstone.com/wp-content/upload...  2025-01-06T02:57:18Z
# 2  https://img.zeit.de/news/2025-01/20/nach-tod-v...  2025-01-20T08:57:18Z
# 3  https://img.zeit.de/news/2025-01/14/17-jaehrig...  2025-01-14T13:48:25Z
# 4  https://images2.minutemediacdn.com/image/uploa...  2025-01-06T18:01:00Z
#
#                                              content source.id    source.name
# 0  As invasive green crabs wreak havoc on Califor...      None            NPR
# 1  Seth Rogen and Catherine O’Hara had Sunday’s G...      None  Rolling Stone
# 2  Nach dem Fund eines toten 17-Jährigen in einem...  die-zeit       Die Zeit
# 3  Ein 17-Jähriger stürzt auf dem Nachhauseweg vo...  die-zeit       Die Zeit
# 4  Invasive species are notorious for being disru...      None   Mental Floss

# %%
parameters = {'apiKey':api,
              'q':'lemons'}

r = requests.get(url,params=parameters)
news_df = pd.json_normalize(r.json(),record_path=['articles'])
news_df.head()
# Out:
#               author                                              title  \
# 0       Nea Arentzen                  What to Bake with A Bag of Lemons
# 1  Heidi Fuller-love  I've followed the Mediterranean diet for over ...
# 2      Heidi Swanson                             How To Dry Citrus Peel
# 3              David                                  Kumquat Marmalade
# 4       Elsie Larson                                        Ginger Shot
#
#                                          description  \
# 0  If you asked me for the one ingredient that I ...
# 1  I've followed the Mediterranean diet for over ...
# 2  Citrus peel is a superhero ingredient. It is o...
# 3  I’ve been on a marmalade bender lately. Well, ...
# 4  This fresh ginger shot recipe makes an excelle...
#
#                                                  url  \
# 0   https://food52.com/blog/28636-best-lemon-recipes
# 1  https://www.businessinsider.com/helpful-advice...
# 2  https://www.101cookbooks.com/how-to-dry-citrus...
# 3  https://www.davidlebovitz.com/kumquat-marmalad...
# 4            https://abeautifulmess.com/ginger-shot/
#
#                                           urlToImage           publishedAt  \
# 0  https://images.food52.com/8e-bVVlhikv2toEQvdtU...  2025-01-17T18:26:24Z
# 1  https://i.insider.com/678ad0bb2fcded5e9073cb9a...  2025-01-17T21:53:53Z
# 2  https://images.101cookbooks.com/how-to-dry-cit...  2025-01-06T19:48:09Z
# 3  https://www.davidlebovitz.com/wp-content/uploa...  2025-01-19T14:41:57Z
# 4  https://abeautifulmess.com/wp-content/uploads/...  2025-01-10T14:00:00Z
#
#                                              content         source.id  \
# 0  If you asked me for the one ingredient that I ...              None
# 1  I have a few tricks for sticking to the Medite...  business-insider
# 2  We buy loads of citrus every week to squeeze i...              None
# 3  I’ve been on a marmalade bender lately. Well, ...              None
# 4  This fresh ginger shot recipe makes an excelle...              None
#
#          source.name
# 0         Food52.com
# 1   Business Insider
# 2   101cookbooks.com
# 3  Davidlebovitz.com
# 4   A Beautiful Mess
