# %% [markdown]
# # Live Coding Session Module 02

# %% [markdown]
# ## Gallup Poll # 1936-0053
# * Teachers' Oath/Government Loans for Farmers/Employers Insurance Contributions/Presidential Candidates [Roper #31087039]

# %%
import pandas as pd
import numpy as np

# %%
gallup = pd.read_csv('data/USAIPO1936-0053.csv')

# %%
gallup.head(3).T
# Out:
#                                    0                      1  \
# form                             NaN                    NaN
# state                        Indiana               Illinois
# region                  East Central           East Central
# female                          Male                   Male
# age                              NaN                    NaN
# class                            Av+                    Av+
# OCCUPATION1          Skilled workers        Skilled workers
# OCCUPATION2                      NaN                    NaN
# OCCUPATION3                      NaN                    NaN
# black                            NaN                    NaN
# size                           Urban                  Urban
# education                        NaN                    NaN
# AGE_3WAY                         NaN                    NaN
# AGE40                            NaN                    NaN
# OCC8                           Labor                  Labor
# ...

# %%
pd.crosstab(gallup['Q3'],gallup['Q5A'])
# Out:
# Q5A  Landon  Lemke  Other party  Roosevelt  Thomas
# Q3
# No      921     41            6        442      10
# Yes     820    109            6       2048      41

# %% [markdown]
# ## Dataset 2

# %%
russia = pd.read_csv('data/31121191.csv',encoding='latin')

# %%
#pd.set_option('display.max_rows'=63)
russia.head(3).T
# Out:
#                                       0  \
# ID                     0791e2f21e4cea8f
# SEX                                Male
# AGE                                  63
# EDU      Incomplete secondary education
# REGION       The Trans-Baikal Territory
# ...                                 ...
# ss6
# ss7_1
# ss7_2
# ss8
# weight1                        1.466481
#
#                                                       1  \
# ID                                     0791e3674d8ced7d
# SEX                                                Male
# AGE                                                  47
# EDU      Secondary special education (technical school)
# REGION                    The Primorsky Krai/ Territory
# ...                                                 ...
# ss6
# ss7_1
# ss7_2
# ss8
# weight1                                        1.249258
#
#                                                       2
# ID                                     0791e2f9facceb98
# ...

# %%
russia['Q2_1'].value_counts()
# Out:
# Q2_1
# Approve        37597
# Disapprove      6818
# Do not know     3768
# Name: count, dtype: int64

# %% [markdown]
# ## Third Dataset: Pakistan

# %%
widthsd = pd.read_csv('data/USIA data widths.csv')
widthsd
# Out:
#      Field  Width
# 0        1      4
# 1        2      3
# 2        3      1
# 3        4      1
# 4        5      1
# ..     ...    ...
# 131    132      2
# 132    133      1
# 133    134      1
# 134    135      1
# 135    136      1
#
# [136 rows x 2 columns]

# %%
usia = pd.read_fwf('data/i20068.dat',widths=widthsd['Width'],header=None)
usia.head(3).T
# Out:
#          0      1      2
# 0        1      2      3
# 1    155.0  155.0  155.0
# 2      2.0    2.0    2.0
# 3      1.0    1.0    1.0
# 4      2.0    2.0    2.0
# ..     ...    ...    ...
# 131    4.0    NaN    NaN
# 132    NaN    NaN    NaN
# 133    6.0    NaN    NaN
# 134    4.0    3.0    5.0
# 135    NaN    NaN    NaN
#
# [136 rows x 3 columns]
